# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    # it must be float32, cannot be int32
    input_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels))
    input_z = tf.placeholder(tf.float32, (None, z_dim))
    learn_rate = tf.placeholder(tf.float32, [])

    return input_real, input_z, learn_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    
    alpha=0.1
    kernel_init = tf.random_normal_initializer(stddev=0.02)
    
    with tf.variable_scope('discriminator', reuse=reuse):
        x = tf.layers.conv2d(images, 64, (5,5), kernel_initializer=kernel_init, strides=(2,2), padding='same')
        x = tf.maximum(x * alpha, x)
        # layer1 shape (?, 14, 14, 64)
        
        x = tf.layers.conv2d(x, 128, (5,5), kernel_initializer=kernel_init, strides=(2,2), padding='same')
        x = tf.maximum(x * alpha, x)
        x = tf.layers.batch_normalization(x, training=True)
        # layer2 shape (?, 7, 7, 128)
        
        x = tf.layers.conv2d(x, 256, (5,5), kernel_initializer=kernel_init, strides=(2,2), padding='same')
        x = tf.maximum(x * alpha, x)
        x = tf.layers.batch_normalization(x, training=True)
        # layer3 shape (?, 4, 4, 256)
        
        x = tf.contrib.layers.flatten(x)
        # flatten layer shape (?, 4096)
        
        logits = tf.layers.dense(x, 1)
        # logits shape (?, 1)
        out = tf.sigmoid(logits)
        # out shape (?, 1)

    return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    reuse = not is_train
    alpha=0.1
    kernel_init = tf.random_normal_initializer(stddev=0.02)
    
    # out_channel_dim = 5 in this test case
    
    with tf.variable_scope('generator', reuse=reuse):
        # First fully connected layer
        x = tf.layers.dense(z, 7*7*256)
        # layer1 shape (?, 12544)

        # Reshape it to start the convolutional stack
        x = tf.reshape(x, (-1, 7, 7, 256))
        x = tf.maximum(x * alpha, x)
        x = tf.layers.batch_normalization(x, training=is_train)
        
        x = tf.layers.conv2d_transpose(x, 128, (5, 5), kernel_initializer=kernel_init, strides=(2, 2), padding='same')
        x = tf.maximum(x * alpha, x)
        x = tf.layers.batch_normalization(x, training=is_train)
        # layer2 shape (?, 14, 14, 128)
        
        x = tf.layers.conv2d_transpose(x, 64, (5, 5), kernel_initializer=kernel_init, strides=(2, 2), padding='same')
        x = tf.maximum(x * alpha, x)
        x = tf.layers.batch_normalization(x, training=is_train)
        # layer3 shape (?, 28, 28, 64)
        
        # Output layer
        logits = tf.layers.conv2d_transpose(x, out_channel_dim, (3, 3), kernel_initializer=kernel_init, strides=(1,1), padding='same')
        # logits shape (?, 28, 28, 5)
        
        out = tf.tanh(logits)
        # out shape (?, 28, 28, 5)
    
    # 28 x 28 x out_channel_dim images = 28 * 28 * 5
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    
    # Copied from DCGAN.ipynb
    
    # signature: generator(z, out_channel_dim, is_train=True)
    g_model = generator(input_z, out_channel_dim)
    
    # signature: discriminator(images, reuse=False)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    smooth = 0.9
    smooth_real_labels = tf.ones_like(d_model_real) * smooth
    
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=smooth_real_labels))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    
    # Copied from DCGAN.ipynb
    
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    d_updates = [opt for opt in update_ops if opt.name.startswith('discriminator')]
    g_updates = [opt for opt in update_ops if opt.name.startswith('generator')]

    with tf.control_dependencies(d_updates):
        d_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)

    with tf.control_dependencies(g_updates):
        g_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    
    steps = 0
    
    losses = []
    
    _, image_width, image_height, image_channels = data_shape
    
    # signature: model_inputs(image_width, image_height, image_channels, z_dim)
    # return: input_real, input_z, learn_rate
    input_real, input_z, learn_rate = model_inputs(image_width, image_height, image_channels, z_dim)
    
    # signature: model_loss(input_real, input_z, out_channel_dim)
    # return: d_loss, g_loss
    d_loss, g_loss = model_loss(input_real, input_z, image_channels)
    
    # signature: model_opt(d_loss, g_loss, learning_rate, beta1)
    # return: d_train_opt, g_train_opt
    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    saver = tf.train.Saver()

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_idx, batch_images in enumerate(get_batches(batch_size)):
                # TODO: Train Model
                
                steps += 1
                batch_images *= 2
                
                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                # Run optimizers
                _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, 
                                                     input_z: batch_z, 
                                                     learn_rate:learning_rate})
                _ = sess.run(g_train_opt, feed_dict={input_z: batch_z, 
                                                     learn_rate:learning_rate})
                
                if steps % 10 == 0:
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                          "Batch {}...".format(batch_idx+1),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    
                    # Save losses to view after training
                    losses.append((train_loss_d, train_loss_g))
                    
                if steps % 100 == 0:
                    # Signature: show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode)
                    show_generator_output(sess, 4, input_z, image_channels, data_image_mode)
    
        saver.save(sess, './checkpoints/generator.ckpt')

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Batch 10... Discriminator Loss: 1.2823... Generator Loss: 0.7588
# Epoch 1/2... Batch 20... Discriminator Loss: 0.6974... Generator Loss: 1.5534
# Epoch 1/2... Batch 30... Discriminator Loss: 0.4623... Generator Loss: 2.6297
# Epoch 1/2... Batch 40... Discriminator Loss: 0.4029... Generator Loss: 4.7832
# Epoch 1/2... Batch 50... Discriminator Loss: 0.3980... Generator Loss: 3.3960
# Epoch 1/2... Batch 60... Discriminator Loss: 0.4639... Generator Loss: 4.3563
# Epoch 1/2... Batch 70... Discriminator Loss: 0.3860... Generator Loss: 5.0101
# Epoch 1/2... Batch 80... Discriminator Loss: 0.4145... Generator Loss: 4.9281
# Epoch 1/2... Batch 90... Discriminator Loss: 0.3696... Generator Loss: 5.8793
# Epoch 1/2... Batch 100... Discriminator Loss: 0.3893... Generator Loss: 3.5299
# Epoch 1/2... Batch 110... Discriminator Loss: 0.4100... Generator Loss: 3.7124
# Epoch 1/2... Batch 120... Discriminator Loss: 0.5675... Generator Loss: 2.1856
# Epoch 1/2... Batch 130... Discriminator Loss: 1.1362... Generator Loss: 0.9963
# Epoch 1/2... Batch 140... Discriminator Loss: 0.6279... Generator Loss: 1.7514
# Epoch 1/2... Batch 150... Discriminator Loss: 0.9124... Generator Loss: 1.3039
# Epoch 1/2... Batch 160... Discriminator Loss: 0.7330... Generator Loss: 1.5939
# Epoch 1/2... Batch 170... Discriminator Loss: 2.7552... Generator Loss: 6.5051
# Epoch 1/2... Batch 180... Discriminator Loss: 0.8084... Generator Loss: 3.2736
# Epoch 1/2... Batch 190... Discriminator Loss: 0.6855... Generator Loss: 1.3617
# Epoch 1/2... Batch 200... Discriminator Loss: 0.6729... Generator Loss: 2.1634
# Epoch 1/2... Batch 210... Discriminator Loss: 0.9565... Generator Loss: 3.0431
# Epoch 1/2... Batch 220... Discriminator Loss: 0.8717... Generator Loss: 2.9528
# Epoch 1/2... Batch 230... Discriminator Loss: 1.1526... Generator Loss: 0.6965
# Epoch 1/2... Batch 240... Discriminator Loss: 0.7131... Generator Loss: 1.4903
# Epoch 1/2... Batch 250... Discriminator Loss: 1.1501... Generator Loss: 0.7228
# Epoch 1/2... Batch 260... Discriminator Loss: 1.0458... Generator Loss: 0.7848
# Epoch 1/2... Batch 270... Discriminator Loss: 0.6766... Generator Loss: 2.1780
# Epoch 1/2... Batch 280... Discriminator Loss: 0.7852... Generator Loss: 1.4526
# Epoch 1/2... Batch 290... Discriminator Loss: 0.9745... Generator Loss: 0.9248
# Epoch 1/2... Batch 300... Discriminator Loss: 0.7540... Generator Loss: 1.3800
# Epoch 1/2... Batch 310... Discriminator Loss: 1.3331... Generator Loss: 0.5760
# Epoch 1/2... Batch 320... Discriminator Loss: 0.7570... Generator Loss: 1.7870
# Epoch 1/2... Batch 330... Discriminator Loss: 0.6623... Generator Loss: 1.7373
# Epoch 1/2... Batch 340... Discriminator Loss: 0.8356... Generator Loss: 1.1168
# Epoch 1/2... Batch 350... Discriminator Loss: 0.9745... Generator Loss: 0.9604
# Epoch 1/2... Batch 360... Discriminator Loss: 0.7006... Generator Loss: 2.2188
# Epoch 1/2... Batch 370... Discriminator Loss: 0.7983... Generator Loss: 1.5172
# Epoch 1/2... Batch 380... Discriminator Loss: 0.7874... Generator Loss: 1.4033
# Epoch 1/2... Batch 390... Discriminator Loss: 0.9693... Generator Loss: 1.1549
# Epoch 1/2... Batch 400... Discriminator Loss: 1.3648... Generator Loss: 0.5507
# Epoch 1/2... Batch 410... Discriminator Loss: 1.0296... Generator Loss: 2.9186
# Epoch 1/2... Batch 420... Discriminator Loss: 1.0228... Generator Loss: 0.8753
# Epoch 1/2... Batch 430... Discriminator Loss: 0.9594... Generator Loss: 1.4499
# Epoch 1/2... Batch 440... Discriminator Loss: 0.9296... Generator Loss: 1.1613
# Epoch 1/2... Batch 450... Discriminator Loss: 1.0349... Generator Loss: 0.8458
# Epoch 1/2... Batch 460... Discriminator Loss: 0.8862... Generator Loss: 1.1221
# Epoch 1/2... Batch 470... Discriminator Loss: 0.9884... Generator Loss: 0.9060
# Epoch 1/2... Batch 480... Discriminator Loss: 1.4868... Generator Loss: 0.4781
# Epoch 1/2... Batch 490... Discriminator Loss: 0.8681... Generator Loss: 1.8342
# Epoch 1/2... Batch 500... Discriminator Loss: 1.1633... Generator Loss: 2.5877
# Epoch 1/2... Batch 510... Discriminator Loss: 1.1412... Generator Loss: 0.7208
# Epoch 1/2... Batch 520... Discriminator Loss: 1.3562... Generator Loss: 0.5613
# Epoch 1/2... Batch 530... Discriminator Loss: 0.9738... Generator Loss: 0.9787
# Epoch 1/2... Batch 540... Discriminator Loss: 1.3232... Generator Loss: 0.6306
# Epoch 1/2... Batch 550... Discriminator Loss: 0.9546... Generator Loss: 1.1127
# Epoch 1/2... Batch 560... Discriminator Loss: 1.4145... Generator Loss: 0.5383
# Epoch 1/2... Batch 570... Discriminator Loss: 0.8535... Generator Loss: 1.6760
# Epoch 1/2... Batch 580... Discriminator Loss: 1.0617... Generator Loss: 0.8399
# Epoch 1/2... Batch 590... Discriminator Loss: 0.9901... Generator Loss: 0.9971
# Epoch 1/2... Batch 600... Discriminator Loss: 1.0083... Generator Loss: 2.3415
# Epoch 1/2... Batch 610... Discriminator Loss: 0.9166... Generator Loss: 1.2028
# Epoch 1/2... Batch 620... Discriminator Loss: 0.9509... Generator Loss: 1.0069
# Epoch 1/2... Batch 630... Discriminator Loss: 0.8129... Generator Loss: 1.5533
# Epoch 1/2... Batch 640... Discriminator Loss: 0.9906... Generator Loss: 0.9207
# Epoch 1/2... Batch 650... Discriminator Loss: 1.3173... Generator Loss: 0.5657
# Epoch 1/2... Batch 660... Discriminator Loss: 0.9143... Generator Loss: 1.0816
# Epoch 1/2... Batch 670... Discriminator Loss: 0.8409... Generator Loss: 1.2252
# Epoch 1/2... Batch 680... Discriminator Loss: 0.7878... Generator Loss: 1.6829
# Epoch 1/2... Batch 690... Discriminator Loss: 0.8310... Generator Loss: 1.1701
# Epoch 1/2... Batch 700... Discriminator Loss: 0.8726... Generator Loss: 1.3577
# Epoch 1/2... Batch 710... Discriminator Loss: 0.9884... Generator Loss: 0.8751
# Epoch 1/2... Batch 720... Discriminator Loss: 1.0508... Generator Loss: 0.7950
# Epoch 1/2... Batch 730... Discriminator Loss: 0.9330... Generator Loss: 0.9934
# Epoch 1/2... Batch 740... Discriminator Loss: 0.9723... Generator Loss: 0.9994
# Epoch 1/2... Batch 750... Discriminator Loss: 0.7794... Generator Loss: 1.6945
# Epoch 1/2... Batch 760... Discriminator Loss: 0.7794... Generator Loss: 1.6852
# Epoch 1/2... Batch 770... Discriminator Loss: 0.8819... Generator Loss: 1.1856
# Epoch 1/2... Batch 780... Discriminator Loss: 0.7279... Generator Loss: 1.5669
# Epoch 1/2... Batch 790... Discriminator Loss: 0.8446... Generator Loss: 1.6993
# Epoch 1/2... Batch 800... Discriminator Loss: 0.9145... Generator Loss: 1.5728
# Epoch 1/2... Batch 810... Discriminator Loss: 0.9652... Generator Loss: 2.2561
# Epoch 1/2... Batch 820... Discriminator Loss: 1.0083... Generator Loss: 0.8692
# Epoch 1/2... Batch 830... Discriminator Loss: 0.9386... Generator Loss: 1.3731
# Epoch 1/2... Batch 840... Discriminator Loss: 1.2329... Generator Loss: 0.6708
# Epoch 1/2... Batch 850... Discriminator Loss: 0.9826... Generator Loss: 0.9235
# Epoch 1/2... Batch 860... Discriminator Loss: 0.8581... Generator Loss: 1.2114
# Epoch 1/2... Batch 870... Discriminator Loss: 0.7836... Generator Loss: 1.5750
# Epoch 1/2... Batch 880... Discriminator Loss: 0.9616... Generator Loss: 0.9344
# Epoch 1/2... Batch 890... Discriminator Loss: 0.7800... Generator Loss: 1.6496
# Epoch 1/2... Batch 900... Discriminator Loss: 1.0625... Generator Loss: 0.8218
# Epoch 1/2... Batch 910... Discriminator Loss: 1.0247... Generator Loss: 0.8754
# Epoch 1/2... Batch 920... Discriminator Loss: 1.0260... Generator Loss: 0.8819
# Epoch 1/2... Batch 930... Discriminator Loss: 0.9196... Generator Loss: 1.0622
# Epoch 2/2... Batch 3... Discriminator Loss: 0.9211... Generator Loss: 1.0677
# Epoch 2/2... Batch 13... Discriminator Loss: 0.9451... Generator Loss: 0.9827
# Epoch 2/2... Batch 23... Discriminator Loss: 0.7115... Generator Loss: 1.7094
# Epoch 2/2... Batch 33... Discriminator Loss: 0.7430... Generator Loss: 1.2746
# Epoch 2/2... Batch 43... Discriminator Loss: 0.6518... Generator Loss: 1.9291
# Epoch 2/2... Batch 53... Discriminator Loss: 0.8285... Generator Loss: 1.2615
# Epoch 2/2... Batch 63... Discriminator Loss: 1.6248... Generator Loss: 0.3953
# Epoch 2/2... Batch 73... Discriminator Loss: 0.8741... Generator Loss: 1.3598
# Epoch 2/2... Batch 83... Discriminator Loss: 0.8890... Generator Loss: 1.1794
# Epoch 2/2... Batch 93... Discriminator Loss: 1.0725... Generator Loss: 0.7984
# Epoch 2/2... Batch 103... Discriminator Loss: 0.9772... Generator Loss: 0.9925
# Epoch 2/2... Batch 113... Discriminator Loss: 1.5902... Generator Loss: 0.4681
# Epoch 2/2... Batch 123... Discriminator Loss: 1.2894... Generator Loss: 0.6235
# Epoch 2/2... Batch 133... Discriminator Loss: 1.0423... Generator Loss: 0.9102
# Epoch 2/2... Batch 143... Discriminator Loss: 1.1843... Generator Loss: 0.7210
# Epoch 2/2... Batch 153... Discriminator Loss: 1.0372... Generator Loss: 0.9057
# Epoch 2/2... Batch 163... Discriminator Loss: 0.7881... Generator Loss: 1.3735
# Epoch 2/2... Batch 173... Discriminator Loss: 0.9812... Generator Loss: 2.0970
# Epoch 2/2... Batch 183... Discriminator Loss: 0.8829... Generator Loss: 1.2261
# Epoch 2/2... Batch 193... Discriminator Loss: 0.9001... Generator Loss: 1.0084
# Epoch 2/2... Batch 203... Discriminator Loss: 0.7380... Generator Loss: 1.4327
# Epoch 2/2... Batch 213... Discriminator Loss: 1.0757... Generator Loss: 0.8169
# Epoch 2/2... Batch 223... Discriminator Loss: 1.0193... Generator Loss: 0.8490
# Epoch 2/2... Batch 233... Discriminator Loss: 1.2770... Generator Loss: 0.6479
# Epoch 2/2... Batch 243... Discriminator Loss: 1.3752... Generator Loss: 0.5493
# Epoch 2/2... Batch 253... Discriminator Loss: 1.1967... Generator Loss: 0.7054
# Epoch 2/2... Batch 263... Discriminator Loss: 0.8989... Generator Loss: 1.1775
# Epoch 2/2... Batch 273... Discriminator Loss: 0.7758... Generator Loss: 1.7127
# Epoch 2/2... Batch 283... Discriminator Loss: 0.9609... Generator Loss: 0.9878
# Epoch 2/2... Batch 293... Discriminator Loss: 1.5370... Generator Loss: 0.4666
# Epoch 2/2... Batch 303... Discriminator Loss: 0.8013... Generator Loss: 1.3654
# Epoch 2/2... Batch 313... Discriminator Loss: 0.9457... Generator Loss: 0.9495
# Epoch 2/2... Batch 323... Discriminator Loss: 0.8336... Generator Loss: 1.1178
# Epoch 2/2... Batch 333... Discriminator Loss: 0.8805... Generator Loss: 1.1205
# Epoch 2/2... Batch 343... Discriminator Loss: 0.9555... Generator Loss: 0.9838
# Epoch 2/2... Batch 353... Discriminator Loss: 1.4860... Generator Loss: 0.4822
# Epoch 2/2... Batch 363... Discriminator Loss: 0.9321... Generator Loss: 0.9893
# Epoch 2/2... Batch 373... Discriminator Loss: 1.0761... Generator Loss: 0.7790
# Epoch 2/2... Batch 383... Discriminator Loss: 1.1677... Generator Loss: 0.7357
# Epoch 2/2... Batch 393... Discriminator Loss: 1.1349... Generator Loss: 0.7396
# Epoch 2/2... Batch 403... Discriminator Loss: 0.7531... Generator Loss: 1.7191
# Epoch 2/2... Batch 413... Discriminator Loss: 0.9802... Generator Loss: 0.9119
# Epoch 2/2... Batch 423... Discriminator Loss: 1.2253... Generator Loss: 0.6439
# Epoch 2/2... Batch 433... Discriminator Loss: 0.5836... Generator Loss: 1.7571
# Epoch 2/2... Batch 443... Discriminator Loss: 2.5660... Generator Loss: 0.2277
# Epoch 2/2... Batch 453... Discriminator Loss: 0.7655... Generator Loss: 1.4085
# Epoch 2/2... Batch 463... Discriminator Loss: 1.0803... Generator Loss: 0.8789
# Epoch 2/2... Batch 473... Discriminator Loss: 0.7601... Generator Loss: 1.5205
# Epoch 2/2... Batch 483... Discriminator Loss: 0.8750... Generator Loss: 1.2783
# Epoch 2/2... Batch 493... Discriminator Loss: 1.1682... Generator Loss: 0.7591
# Epoch 2/2... Batch 503... Discriminator Loss: 0.8601... Generator Loss: 1.1625
# Epoch 2/2... Batch 513... Discriminator Loss: 1.0648... Generator Loss: 0.8104
# Epoch 2/2... Batch 523... Discriminator Loss: 0.7237... Generator Loss: 2.0569
# Epoch 2/2... Batch 533... Discriminator Loss: 0.7598... Generator Loss: 1.2521
# Epoch 2/2... Batch 543... Discriminator Loss: 0.8436... Generator Loss: 1.1553
# Epoch 2/2... Batch 553... Discriminator Loss: 1.7010... Generator Loss: 0.4883
# Epoch 2/2... Batch 563... Discriminator Loss: 0.8491... Generator Loss: 1.4948
# Epoch 2/2... Batch 573... Discriminator Loss: 1.0062... Generator Loss: 0.8717
# Epoch 2/2... Batch 583... Discriminator Loss: 0.9148... Generator Loss: 0.9868
# Epoch 2/2... Batch 593... Discriminator Loss: 0.7847... Generator Loss: 1.2365
# Epoch 2/2... Batch 603... Discriminator Loss: 1.6092... Generator Loss: 0.4471
# Epoch 2/2... Batch 613... Discriminator Loss: 0.7061... Generator Loss: 1.7129
# Epoch 2/2... Batch 623... Discriminator Loss: 0.7149... Generator Loss: 1.6255
# Epoch 2/2... Batch 633... Discriminator Loss: 1.0487... Generator Loss: 0.8469
# Epoch 2/2... Batch 643... Discriminator Loss: 0.6836... Generator Loss: 1.9473
# Epoch 2/2... Batch 653... Discriminator Loss: 0.6984... Generator Loss: 2.0010
# Epoch 2/2... Batch 663... Discriminator Loss: 0.8173... Generator Loss: 1.2964
# Epoch 2/2... Batch 673... Discriminator Loss: 0.9007... Generator Loss: 1.1542
# Epoch 2/2... Batch 683... Discriminator Loss: 0.9029... Generator Loss: 1.0650
# Epoch 2/2... Batch 693... Discriminator Loss: 0.5591... Generator Loss: 2.1082
# Epoch 2/2... Batch 703... Discriminator Loss: 0.7136... Generator Loss: 1.4296
# Epoch 2/2... Batch 713... Discriminator Loss: 0.7001... Generator Loss: 1.7475
# Epoch 2/2... Batch 723... Discriminator Loss: 0.8622... Generator Loss: 1.1796
# Epoch 2/2... Batch 733... Discriminator Loss: 0.6169... Generator Loss: 1.7777
# Epoch 2/2... Batch 743... Discriminator Loss: 0.7688... Generator Loss: 1.5105
# Epoch 2/2... Batch 753... Discriminator Loss: 0.8527... Generator Loss: 1.2743
# Epoch 2/2... Batch 763... Discriminator Loss: 0.8293... Generator Loss: 1.1580
# Epoch 2/2... Batch 773... Discriminator Loss: 0.9263... Generator Loss: 1.0483
# Epoch 2/2... Batch 783... Discriminator Loss: 0.9602... Generator Loss: 0.9516
# Epoch 2/2... Batch 793... Discriminator Loss: 0.9434... Generator Loss: 0.8790
# Epoch 2/2... Batch 803... Discriminator Loss: 1.7911... Generator Loss: 0.3508
# Epoch 2/2... Batch 813... Discriminator Loss: 0.9137... Generator Loss: 1.0084
# Epoch 2/2... Batch 823... Discriminator Loss: 0.7925... Generator Loss: 1.2436
# Epoch 2/2... Batch 833... Discriminator Loss: 0.6616... Generator Loss: 1.5852
# Epoch 2/2... Batch 843... Discriminator Loss: 0.6820... Generator Loss: 1.5165
# Epoch 2/2... Batch 853... Discriminator Loss: 0.7090... Generator Loss: 1.4518
# Epoch 2/2... Batch 863... Discriminator Loss: 1.0193... Generator Loss: 1.0059
# Epoch 2/2... Batch 873... Discriminator Loss: 0.8680... Generator Loss: 1.1309
# Epoch 2/2... Batch 883... Discriminator Loss: 1.2456... Generator Loss: 0.6396
# Epoch 2/2... Batch 893... Discriminator Loss: 0.8222... Generator Loss: 1.5965
# Epoch 2/2... Batch 903... Discriminator Loss: 1.0536... Generator Loss: 0.8626
# Epoch 2/2... Batch 913... Discriminator Loss: 0.6775... Generator Loss: 1.5697
# Epoch 2/2... Batch 923... Discriminator Loss: 0.9165... Generator Loss: 1.0144
# Epoch 2/2... Batch 933... Discriminator Loss: 1.0147... Generator Loss: 0.8861

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 256
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Batch 10... Discriminator Loss: 0.6502... Generator Loss: 1.8685
# Epoch 1/1... Batch 20... Discriminator Loss: 0.4714... Generator Loss: 3.1230
# Epoch 1/1... Batch 30... Discriminator Loss: 0.4241... Generator Loss: 6.4097
# Epoch 1/1... Batch 40... Discriminator Loss: 0.4148... Generator Loss: 5.6888
# Epoch 1/1... Batch 50... Discriminator Loss: 0.4288... Generator Loss: 4.2874
# Epoch 1/1... Batch 60... Discriminator Loss: 0.5411... Generator Loss: 4.7072
# Epoch 1/1... Batch 70... Discriminator Loss: 0.6294... Generator Loss: 2.2296
# Epoch 1/1... Batch 80... Discriminator Loss: 0.4962... Generator Loss: 2.5152
# Epoch 1/1... Batch 90... Discriminator Loss: 0.5219... Generator Loss: 2.6579
# Epoch 1/1... Batch 100... Discriminator Loss: 0.4883... Generator Loss: 2.8957
# Epoch 1/1... Batch 110... Discriminator Loss: 0.5558... Generator Loss: 2.9670
# Epoch 1/1... Batch 120... Discriminator Loss: 0.8648... Generator Loss: 1.2544
# Epoch 1/1... Batch 130... Discriminator Loss: 1.1684... Generator Loss: 0.8957
# Epoch 1/1... Batch 140... Discriminator Loss: 1.4327... Generator Loss: 0.7197
# Epoch 1/1... Batch 150... Discriminator Loss: 1.0498... Generator Loss: 1.5277
# Epoch 1/1... Batch 160... Discriminator Loss: 1.7180... Generator Loss: 0.3905
# Epoch 1/1... Batch 170... Discriminator Loss: 1.1778... Generator Loss: 1.8809
# Epoch 1/1... Batch 180... Discriminator Loss: 0.9007... Generator Loss: 1.8141
# Epoch 1/1... Batch 190... Discriminator Loss: 1.3725... Generator Loss: 3.0067
# Epoch 1/1... Batch 200... Discriminator Loss: 1.8743... Generator Loss: 0.4043
# Epoch 1/1... Batch 210... Discriminator Loss: 1.1207... Generator Loss: 1.2654
# Epoch 1/1... Batch 220... Discriminator Loss: 1.4850... Generator Loss: 0.5850
# Epoch 1/1... Batch 230... Discriminator Loss: 1.2606... Generator Loss: 0.9556
# Epoch 1/1... Batch 240... Discriminator Loss: 1.4264... Generator Loss: 0.6101
# Epoch 1/1... Batch 250... Discriminator Loss: 1.5648... Generator Loss: 0.5035
# Epoch 1/1... Batch 260... Discriminator Loss: 1.2360... Generator Loss: 1.6674
# Epoch 1/1... Batch 270... Discriminator Loss: 1.1744... Generator Loss: 1.3791
# Epoch 1/1... Batch 280... Discriminator Loss: 1.1183... Generator Loss: 1.1442
# Epoch 1/1... Batch 290... Discriminator Loss: 1.3760... Generator Loss: 0.7162
# Epoch 1/1... Batch 300... Discriminator Loss: 1.0219... Generator Loss: 1.4407
# Epoch 1/1... Batch 310... Discriminator Loss: 1.2403... Generator Loss: 0.8460
# Epoch 1/1... Batch 320... Discriminator Loss: 1.1735... Generator Loss: 1.8045
# Epoch 1/1... Batch 330... Discriminator Loss: 1.7528... Generator Loss: 1.7447
# Epoch 1/1... Batch 340... Discriminator Loss: 1.3476... Generator Loss: 0.7168
# Epoch 1/1... Batch 350... Discriminator Loss: 1.3189... Generator Loss: 0.7354
# Epoch 1/1... Batch 360... Discriminator Loss: 1.3241... Generator Loss: 1.0367
# Epoch 1/1... Batch 370... Discriminator Loss: 1.2720... Generator Loss: 1.2490
# Epoch 1/1... Batch 380... Discriminator Loss: 1.2419... Generator Loss: 0.8288
# Epoch 1/1... Batch 390... Discriminator Loss: 1.2701... Generator Loss: 1.0144
# Epoch 1/1... Batch 400... Discriminator Loss: 1.2718... Generator Loss: 1.1813
# Epoch 1/1... Batch 410... Discriminator Loss: 1.3016... Generator Loss: 1.5905
# Epoch 1/1... Batch 420... Discriminator Loss: 1.0816... Generator Loss: 1.2571
# Epoch 1/1... Batch 430... Discriminator Loss: 1.1899... Generator Loss: 1.0555
# Epoch 1/1... Batch 440... Discriminator Loss: 1.2618... Generator Loss: 1.2804
# Epoch 1/1... Batch 450... Discriminator Loss: 1.1878... Generator Loss: 0.9741
# Epoch 1/1... Batch 460... Discriminator Loss: 1.1834... Generator Loss: 1.4364
# Epoch 1/1... Batch 470... Discriminator Loss: 1.2324... Generator Loss: 0.8851
# Epoch 1/1... Batch 480... Discriminator Loss: 1.2403... Generator Loss: 0.8480
# Epoch 1/1... Batch 490... Discriminator Loss: 1.2693... Generator Loss: 1.0231
# Epoch 1/1... Batch 500... Discriminator Loss: 1.2259... Generator Loss: 0.7523
# Epoch 1/1... Batch 510... Discriminator Loss: 1.2804... Generator Loss: 0.7915
# Epoch 1/1... Batch 520... Discriminator Loss: 1.1631... Generator Loss: 1.0532
# Epoch 1/1... Batch 530... Discriminator Loss: 1.1546... Generator Loss: 1.2685
# Epoch 1/1... Batch 540... Discriminator Loss: 1.2197... Generator Loss: 0.7831
# Epoch 1/1... Batch 550... Discriminator Loss: 1.2588... Generator Loss: 0.7263
# Epoch 1/1... Batch 560... Discriminator Loss: 1.1124... Generator Loss: 0.8869
# Epoch 1/1... Batch 570... Discriminator Loss: 1.2895... Generator Loss: 1.5025
# Epoch 1/1... Batch 580... Discriminator Loss: 1.1501... Generator Loss: 0.8671
# Epoch 1/1... Batch 590... Discriminator Loss: 1.1533... Generator Loss: 0.8407
# Epoch 1/1... Batch 600... Discriminator Loss: 1.0946... Generator Loss: 0.9342
# Epoch 1/1... Batch 610... Discriminator Loss: 1.3297... Generator Loss: 1.8307
# Epoch 1/1... Batch 620... Discriminator Loss: 1.1128... Generator Loss: 1.1679
# Epoch 1/1... Batch 630... Discriminator Loss: 1.1559... Generator Loss: 0.9248
# Epoch 1/1... Batch 640... Discriminator Loss: 1.3533... Generator Loss: 0.6096
# Epoch 1/1... Batch 650... Discriminator Loss: 1.1973... Generator Loss: 0.7953
# Epoch 1/1... Batch 660... Discriminator Loss: 1.2486... Generator Loss: 1.0587
# Epoch 1/1... Batch 670... Discriminator Loss: 1.1558... Generator Loss: 0.9187
# Epoch 1/1... Batch 680... Discriminator Loss: 1.1395... Generator Loss: 1.6533
# Epoch 1/1... Batch 690... Discriminator Loss: 1.0599... Generator Loss: 1.2432
# Epoch 1/1... Batch 700... Discriminator Loss: 1.0358... Generator Loss: 1.1945
# Epoch 1/1... Batch 710... Discriminator Loss: 1.3692... Generator Loss: 0.5874
# Epoch 1/1... Batch 720... Discriminator Loss: 1.3251... Generator Loss: 0.6715
# Epoch 1/1... Batch 730... Discriminator Loss: 1.2123... Generator Loss: 1.2046
# Epoch 1/1... Batch 740... Discriminator Loss: 0.9805... Generator Loss: 1.2147
# Epoch 1/1... Batch 750... Discriminator Loss: 1.0656... Generator Loss: 1.1098
# Epoch 1/1... Batch 760... Discriminator Loss: 1.2518... Generator Loss: 1.6980
# Epoch 1/1... Batch 770... Discriminator Loss: 1.2364... Generator Loss: 1.2642
# Epoch 1/1... Batch 780... Discriminator Loss: 1.0888... Generator Loss: 1.4962
# Epoch 1/1... Batch 790... Discriminator Loss: 1.1966... Generator Loss: 0.9612

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
