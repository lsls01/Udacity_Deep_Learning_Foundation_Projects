# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return (x - np.min(x)) / (np.max(x) - np.min(x))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    # http://stackoverflow.com/questions/37292872/how-can-i-one-hot-encode-in-python, answer written by Martin Thoma
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, *image_shape], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    # shape of n_classes is 1 dimension
    return tf.placeholder(tf.float32, [None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    input_depth = int(x_tensor.shape[3])
    output_depth = conv_num_outputs
    
    weight_shape = [*conv_ksize, input_depth, output_depth]
    
    weight = tf.Variable(tf.random_normal(weight_shape, stddev=0.1))
    bias = tf.Variable(tf.zeros(output_depth))
    
    conv_strides = [1, *conv_strides, 1]
    
    x_tensor = tf.nn.conv2d(x_tensor, weight, strides=conv_strides, padding='SAME')
    
    x_tensor = tf.nn.bias_add(x_tensor, bias)
    
    x_tensor = tf.nn.relu(x_tensor)
    
    pool_ksize = [1, *pool_ksize, 1]
    pool_strides = [1, *pool_strides, 1]
    
    x_tensor = tf.nn.max_pool(x_tensor, pool_ksize, pool_strides, padding='SAME')
    
    return x_tensor 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    batch_size = x_tensor.get_shape().as_list()[0]
    
    flattened_img_size = x_tensor.get_shape().as_list()[1:]
    flattened_img_size = flattened_img_size[0] * flattened_img_size[1] * flattened_img_size[2]
    
    if batch_size is None:
        return tf.reshape(x_tensor, [-1, flattened_img_size])
    
    return tf.reshape(x_tensor, [batch_size, flattened_img_size])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight_shape = (x_tensor.get_shape().as_list()[1], num_outputs)
    weight = tf.Variable(tf.random_normal(weight_shape, stddev=0.1))
    
    bias = tf.Variable(tf.zeros(num_outputs))
    
    x_tensor = tf.matmul(x_tensor, weight)
    
    x_tensor = tf.add(x_tensor, bias)
    
    x_tensor = tf.nn.relu(x_tensor)
    
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    weight_shape = [x_tensor.get_shape().as_list()[1], num_outputs]
    weight = tf.Variable(tf.random_normal(weight_shape, stddev=0.1))
    
    bias = tf.Variable(tf.zeros(num_outputs))
    
    x_tensor = tf.matmul(x_tensor, weight)
    
    x_tensor = tf.add(x_tensor, bias)
    
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x_tensor = conv2d_maxpool(x, 32, (3, 3), (1, 1), (2, 2), (2, 2))
    x_tensor = conv2d_maxpool(x_tensor, 64, (3, 3), (1, 1), (2, 2), (2, 2))
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x_tensor = flatten(x_tensor)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x_tensor = fully_conn(x_tensor, 512)
    x_tensor = tf.nn.dropout(x_tensor, keep_prob)
    x_tensor = fully_conn(x_tensor, 256)
    x_tensor = tf.nn.dropout(x_tensor, keep_prob)
    x_tensor = fully_conn(x_tensor, 128)
    x_tensor = tf.nn.dropout(x_tensor, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_tensor = output(x_tensor, 10)
    
    
    # TODO: return output
    return output_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0
    })
    
    validation_accuracy = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0
    })

    print(' Loss: {:.4f}   Validation Accuracy: {:.4f}'.format(loss, validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:   Loss: 2.3010   Validation Accuracy: 0.1616
# Epoch  2, CIFAR-10 Batch 1:   Loss: 2.2620   Validation Accuracy: 0.2026
# Epoch  3, CIFAR-10 Batch 1:   Loss: 2.1764   Validation Accuracy: 0.1966
# Epoch  4, CIFAR-10 Batch 1:   Loss: 2.0808   Validation Accuracy: 0.2836
# Epoch  5, CIFAR-10 Batch 1:   Loss: 1.9568   Validation Accuracy: 0.3062
# Epoch  6, CIFAR-10 Batch 1:   Loss: 1.8707   Validation Accuracy: 0.3446
# Epoch  7, CIFAR-10 Batch 1:   Loss: 1.7465   Validation Accuracy: 0.3766
# Epoch  8, CIFAR-10 Batch 1:   Loss: 1.6321   Validation Accuracy: 0.4034
# Epoch  9, CIFAR-10 Batch 1:   Loss: 1.5478   Validation Accuracy: 0.4058
# Epoch 10, CIFAR-10 Batch 1:   Loss: 1.4647   Validation Accuracy: 0.4226
# Epoch 11, CIFAR-10 Batch 1:   Loss: 1.2691   Validation Accuracy: 0.4568
# Epoch 12, CIFAR-10 Batch 1:   Loss: 1.1468   Validation Accuracy: 0.4772
# Epoch 13, CIFAR-10 Batch 1:   Loss: 1.0264   Validation Accuracy: 0.4918
# Epoch 14, CIFAR-10 Batch 1:   Loss: 0.9265   Validation Accuracy: 0.5028
# Epoch 15, CIFAR-10 Batch 1:   Loss: 0.8056   Validation Accuracy: 0.5062
# Epoch 16, CIFAR-10 Batch 1:   Loss: 0.7608   Validation Accuracy: 0.5248
# Epoch 17, CIFAR-10 Batch 1:   Loss: 0.7211   Validation Accuracy: 0.5170
# Epoch 18, CIFAR-10 Batch 1:   Loss: 0.6386   Validation Accuracy: 0.5414
# Epoch 19, CIFAR-10 Batch 1:   Loss: 0.6155   Validation Accuracy: 0.5424
# Epoch 20, CIFAR-10 Batch 1:   Loss: 0.5258   Validation Accuracy: 0.5364
# Epoch 21, CIFAR-10 Batch 1:   Loss: 0.4571   Validation Accuracy: 0.5508
# Epoch 22, CIFAR-10 Batch 1:   Loss: 0.3889   Validation Accuracy: 0.5558
# Epoch 23, CIFAR-10 Batch 1:   Loss: 0.3948   Validation Accuracy: 0.5496
# Epoch 24, CIFAR-10 Batch 1:   Loss: 0.3581   Validation Accuracy: 0.5652
# Epoch 25, CIFAR-10 Batch 1:   Loss: 0.2872   Validation Accuracy: 0.5730
# Epoch 26, CIFAR-10 Batch 1:   Loss: 0.2776   Validation Accuracy: 0.5714
# Epoch 27, CIFAR-10 Batch 1:   Loss: 0.2575   Validation Accuracy: 0.5586
# Epoch 28, CIFAR-10 Batch 1:   Loss: 0.2364   Validation Accuracy: 0.5644
# Epoch 29, CIFAR-10 Batch 1:   Loss: 0.2170   Validation Accuracy: 0.5750
# Epoch 30, CIFAR-10 Batch 1:   Loss: 0.2354   Validation Accuracy: 0.5670
# Epoch 31, CIFAR-10 Batch 1:   Loss: 0.1869   Validation Accuracy: 0.5602
# Epoch 32, CIFAR-10 Batch 1:   Loss: 0.1576   Validation Accuracy: 0.5722
# Epoch 33, CIFAR-10 Batch 1:   Loss: 0.1373   Validation Accuracy: 0.5642
# Epoch 34, CIFAR-10 Batch 1:   Loss: 0.1204   Validation Accuracy: 0.5688
# Epoch 35, CIFAR-10 Batch 1:   Loss: 0.1022   Validation Accuracy: 0.5724
# Epoch 36, CIFAR-10 Batch 1:   Loss: 0.0928   Validation Accuracy: 0.5730
# Epoch 37, CIFAR-10 Batch 1:   Loss: 0.0789   Validation Accuracy: 0.5718
# Epoch 38, CIFAR-10 Batch 1:   Loss: 0.0697   Validation Accuracy: 0.5772
# Epoch 39, CIFAR-10 Batch 1:   Loss: 0.0845   Validation Accuracy: 0.5718
# Epoch 40, CIFAR-10 Batch 1:   Loss: 0.0614   Validation Accuracy: 0.5794
# Epoch 41, CIFAR-10 Batch 1:   Loss: 0.0978   Validation Accuracy: 0.5798
# Epoch 42, CIFAR-10 Batch 1:   Loss: 0.0588   Validation Accuracy: 0.5868
# Epoch 43, CIFAR-10 Batch 1:   Loss: 0.0426   Validation Accuracy: 0.5870
# Epoch 44, CIFAR-10 Batch 1:   Loss: 0.0426   Validation Accuracy: 0.5866
# Epoch 45, CIFAR-10 Batch 1:   Loss: 0.0243   Validation Accuracy: 0.5860
# Epoch 46, CIFAR-10 Batch 1:   Loss: 0.0222   Validation Accuracy: 0.5816
# Epoch 47, CIFAR-10 Batch 1:   Loss: 0.0133   Validation Accuracy: 0.5880
# Epoch 48, CIFAR-10 Batch 1:   Loss: 0.0092   Validation Accuracy: 0.5924
# Epoch 49, CIFAR-10 Batch 1:   Loss: 0.0069   Validation Accuracy: 0.5896
# Epoch 50, CIFAR-10 Batch 1:   Loss: 0.0057   Validation Accuracy: 0.5934
# Epoch 51, CIFAR-10 Batch 1:   Loss: 0.0050   Validation Accuracy: 0.6022
# Epoch 52, CIFAR-10 Batch 1:   Loss: 0.0078   Validation Accuracy: 0.5892
# Epoch 53, CIFAR-10 Batch 1:   Loss: 0.0047   Validation Accuracy: 0.5986
# Epoch 54, CIFAR-10 Batch 1:   Loss: 0.0036   Validation Accuracy: 0.6006
# Epoch 55, CIFAR-10 Batch 1:   Loss: 0.0029   Validation Accuracy: 0.5966
# Epoch 56, CIFAR-10 Batch 1:   Loss: 0.0021   Validation Accuracy: 0.6070
# Epoch 57, CIFAR-10 Batch 1:   Loss: 0.0060   Validation Accuracy: 0.5970
# Epoch 58, CIFAR-10 Batch 1:   Loss: 0.0017   Validation Accuracy: 0.6038
# Epoch 59, CIFAR-10 Batch 1:   Loss: 0.0016   Validation Accuracy: 0.6006
# Epoch 60, CIFAR-10 Batch 1:   Loss: 0.0010   Validation Accuracy: 0.6090
# Epoch 61, CIFAR-10 Batch 1:   Loss: 0.0022   Validation Accuracy: 0.6082
# Epoch 62, CIFAR-10 Batch 1:   Loss: 0.0018   Validation Accuracy: 0.6036
# Epoch 63, CIFAR-10 Batch 1:   Loss: 0.0028   Validation Accuracy: 0.5978
# Epoch 64, CIFAR-10 Batch 1:   Loss: 0.0015   Validation Accuracy: 0.5982
# Epoch 65, CIFAR-10 Batch 1:   Loss: 0.0008   Validation Accuracy: 0.5862
# Epoch 66, CIFAR-10 Batch 1:   Loss: 0.0006   Validation Accuracy: 0.5992
# Epoch 67, CIFAR-10 Batch 1:   Loss: 0.0005   Validation Accuracy: 0.6002
# Epoch 68, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.5942
# Epoch 69, CIFAR-10 Batch 1:   Loss: 0.0005   Validation Accuracy: 0.6074
# Epoch 70, CIFAR-10 Batch 1:   Loss: 0.0006   Validation Accuracy: 0.5956
# Epoch 71, CIFAR-10 Batch 1:   Loss: 0.0004   Validation Accuracy: 0.5954
# Epoch 72, CIFAR-10 Batch 1:   Loss: 0.0005   Validation Accuracy: 0.5968
# Epoch 73, CIFAR-10 Batch 1:   Loss: 0.0005   Validation Accuracy: 0.5922
# Epoch 74, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.6024
# Epoch 75, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.6070
# Epoch 76, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.6000
# Epoch 77, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.6038
# Epoch 78, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.5986
# Epoch 79, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.5900
# Epoch 80, CIFAR-10 Batch 1:   Loss: 0.0004   Validation Accuracy: 0.5994
# Epoch 81, CIFAR-10 Batch 1:   Loss: 0.0007   Validation Accuracy: 0.6034
# Epoch 82, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.6076
# Epoch 83, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.6102
# Epoch 84, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5966
# Epoch 85, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.6024
# Epoch 86, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.6052
# Epoch 87, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.5980
# Epoch 88, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5968
# Epoch 89, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.6078
# Epoch 90, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.6030
# Epoch 91, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.6046
# Epoch 92, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5990
# Epoch 93, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5956
# Epoch 94, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5984
# Epoch 95, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5902
# Epoch 96, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5906
# Epoch 97, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.5992
# Epoch 98, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.5968
# Epoch 99, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.6016
# Epoch 100, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.6004

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:   Loss: 2.2853   Validation Accuracy: 0.1622
# Epoch  1, CIFAR-10 Batch 2:   Loss: 2.1409   Validation Accuracy: 0.2496
# Epoch  1, CIFAR-10 Batch 3:   Loss: 1.9298   Validation Accuracy: 0.3152
# Epoch  1, CIFAR-10 Batch 4:   Loss: 1.8152   Validation Accuracy: 0.3674
# Epoch  1, CIFAR-10 Batch 5:   Loss: 1.7606   Validation Accuracy: 0.3890
# Epoch  2, CIFAR-10 Batch 1:   Loss: 1.8044   Validation Accuracy: 0.4372
# Epoch  2, CIFAR-10 Batch 2:   Loss: 1.6249   Validation Accuracy: 0.4538
# Epoch  2, CIFAR-10 Batch 3:   Loss: 1.4169   Validation Accuracy: 0.4450
# Epoch  2, CIFAR-10 Batch 4:   Loss: 1.4329   Validation Accuracy: 0.4848
# Epoch  2, CIFAR-10 Batch 5:   Loss: 1.4001   Validation Accuracy: 0.5004
# Epoch  3, CIFAR-10 Batch 1:   Loss: 1.3731   Validation Accuracy: 0.4934
# Epoch  3, CIFAR-10 Batch 2:   Loss: 1.3296   Validation Accuracy: 0.4968
# Epoch  3, CIFAR-10 Batch 3:   Loss: 1.0740   Validation Accuracy: 0.5106
# Epoch  3, CIFAR-10 Batch 4:   Loss: 1.2726   Validation Accuracy: 0.5392
# Epoch  3, CIFAR-10 Batch 5:   Loss: 1.1737   Validation Accuracy: 0.5510
# Epoch  4, CIFAR-10 Batch 1:   Loss: 1.1314   Validation Accuracy: 0.5594
# Epoch  4, CIFAR-10 Batch 2:   Loss: 1.0582   Validation Accuracy: 0.5650
# Epoch  4, CIFAR-10 Batch 3:   Loss: 0.8996   Validation Accuracy: 0.5714
# Epoch  4, CIFAR-10 Batch 4:   Loss: 1.0301   Validation Accuracy: 0.5746
# Epoch  4, CIFAR-10 Batch 5:   Loss: 0.9463   Validation Accuracy: 0.5694
# Epoch  5, CIFAR-10 Batch 1:   Loss: 1.0207   Validation Accuracy: 0.5804
# Epoch  5, CIFAR-10 Batch 2:   Loss: 0.8280   Validation Accuracy: 0.5882
# Epoch  5, CIFAR-10 Batch 3:   Loss: 0.7145   Validation Accuracy: 0.5938
# Epoch  5, CIFAR-10 Batch 4:   Loss: 0.8660   Validation Accuracy: 0.6054
# Epoch  5, CIFAR-10 Batch 5:   Loss: 0.7305   Validation Accuracy: 0.5982
# Epoch  6, CIFAR-10 Batch 1:   Loss: 0.8458   Validation Accuracy: 0.6022
# Epoch  6, CIFAR-10 Batch 2:   Loss: 0.6312   Validation Accuracy: 0.6034
# Epoch  6, CIFAR-10 Batch 3:   Loss: 0.6113   Validation Accuracy: 0.6072
# Epoch  6, CIFAR-10 Batch 4:   Loss: 0.6935   Validation Accuracy: 0.6176
# Epoch  6, CIFAR-10 Batch 5:   Loss: 0.5796   Validation Accuracy: 0.6078
# Epoch  7, CIFAR-10 Batch 1:   Loss: 0.7366   Validation Accuracy: 0.6284
# Epoch  7, CIFAR-10 Batch 2:   Loss: 0.5144   Validation Accuracy: 0.6282
# Epoch  7, CIFAR-10 Batch 3:   Loss: 0.5291   Validation Accuracy: 0.6116
# Epoch  7, CIFAR-10 Batch 4:   Loss: 0.5583   Validation Accuracy: 0.6344
# Epoch  7, CIFAR-10 Batch 5:   Loss: 0.5017   Validation Accuracy: 0.6322
# Epoch  8, CIFAR-10 Batch 1:   Loss: 0.6139   Validation Accuracy: 0.6336
# Epoch  8, CIFAR-10 Batch 2:   Loss: 0.4427   Validation Accuracy: 0.6366
# Epoch  8, CIFAR-10 Batch 3:   Loss: 0.3596   Validation Accuracy: 0.6494
# Epoch  8, CIFAR-10 Batch 4:   Loss: 0.4713   Validation Accuracy: 0.6474
# Epoch  8, CIFAR-10 Batch 5:   Loss: 0.3861   Validation Accuracy: 0.6424
# Epoch  9, CIFAR-10 Batch 1:   Loss: 0.5721   Validation Accuracy: 0.6438
# Epoch  9, CIFAR-10 Batch 2:   Loss: 0.3708   Validation Accuracy: 0.6472
# Epoch  9, CIFAR-10 Batch 3:   Loss: 0.2928   Validation Accuracy: 0.6472
# Epoch  9, CIFAR-10 Batch 4:   Loss: 0.3669   Validation Accuracy: 0.6642
# Epoch  9, CIFAR-10 Batch 5:   Loss: 0.3025   Validation Accuracy: 0.6574
# Epoch 10, CIFAR-10 Batch 1:   Loss: 0.4425   Validation Accuracy: 0.6566
# Epoch 10, CIFAR-10 Batch 2:   Loss: 0.3163   Validation Accuracy: 0.6656
# Epoch 10, CIFAR-10 Batch 3:   Loss: 0.2574   Validation Accuracy: 0.6630
# Epoch 10, CIFAR-10 Batch 4:   Loss: 0.3010   Validation Accuracy: 0.6620
# Epoch 10, CIFAR-10 Batch 5:   Loss: 0.2383   Validation Accuracy: 0.6504
# Epoch 11, CIFAR-10 Batch 1:   Loss: 0.3873   Validation Accuracy: 0.6678
# Epoch 11, CIFAR-10 Batch 2:   Loss: 0.2404   Validation Accuracy: 0.6762
# Epoch 11, CIFAR-10 Batch 3:   Loss: 0.2240   Validation Accuracy: 0.6664
# Epoch 11, CIFAR-10 Batch 4:   Loss: 0.2615   Validation Accuracy: 0.6730
# Epoch 11, CIFAR-10 Batch 5:   Loss: 0.1789   Validation Accuracy: 0.6682
# Epoch 12, CIFAR-10 Batch 1:   Loss: 0.3068   Validation Accuracy: 0.6606
# Epoch 12, CIFAR-10 Batch 2:   Loss: 0.2305   Validation Accuracy: 0.6726
# Epoch 12, CIFAR-10 Batch 3:   Loss: 0.1999   Validation Accuracy: 0.6458
# Epoch 12, CIFAR-10 Batch 4:   Loss: 0.1836   Validation Accuracy: 0.6774
# Epoch 12, CIFAR-10 Batch 5:   Loss: 0.1308   Validation Accuracy: 0.6758
# Epoch 13, CIFAR-10 Batch 1:   Loss: 0.2382   Validation Accuracy: 0.6782
# Epoch 13, CIFAR-10 Batch 2:   Loss: 0.1487   Validation Accuracy: 0.6764
# Epoch 13, CIFAR-10 Batch 3:   Loss: 0.1484   Validation Accuracy: 0.6700
# Epoch 13, CIFAR-10 Batch 4:   Loss: 0.1802   Validation Accuracy: 0.6786
# Epoch 13, CIFAR-10 Batch 5:   Loss: 0.1317   Validation Accuracy: 0.6796
# Epoch 14, CIFAR-10 Batch 1:   Loss: 0.2087   Validation Accuracy: 0.6830
# Epoch 14, CIFAR-10 Batch 2:   Loss: 0.1449   Validation Accuracy: 0.6792
# Epoch 14, CIFAR-10 Batch 3:   Loss: 0.1269   Validation Accuracy: 0.6752
# Epoch 14, CIFAR-10 Batch 4:   Loss: 0.1474   Validation Accuracy: 0.6908
# Epoch 14, CIFAR-10 Batch 5:   Loss: 0.0968   Validation Accuracy: 0.6858
# Epoch 15, CIFAR-10 Batch 1:   Loss: 0.2026   Validation Accuracy: 0.6706
# Epoch 15, CIFAR-10 Batch 2:   Loss: 0.1287   Validation Accuracy: 0.6720
# Epoch 15, CIFAR-10 Batch 3:   Loss: 0.1068   Validation Accuracy: 0.6842
# Epoch 15, CIFAR-10 Batch 4:   Loss: 0.1101   Validation Accuracy: 0.6850
# Epoch 15, CIFAR-10 Batch 5:   Loss: 0.0971   Validation Accuracy: 0.6898
# Epoch 16, CIFAR-10 Batch 1:   Loss: 0.1577   Validation Accuracy: 0.6672
# Epoch 16, CIFAR-10 Batch 2:   Loss: 0.0957   Validation Accuracy: 0.6776
# Epoch 16, CIFAR-10 Batch 3:   Loss: 0.1019   Validation Accuracy: 0.6854
# Epoch 16, CIFAR-10 Batch 4:   Loss: 0.0937   Validation Accuracy: 0.6902
# Epoch 16, CIFAR-10 Batch 5:   Loss: 0.0613   Validation Accuracy: 0.6904
# Epoch 17, CIFAR-10 Batch 1:   Loss: 0.0920   Validation Accuracy: 0.6930
# Epoch 17, CIFAR-10 Batch 2:   Loss: 0.0728   Validation Accuracy: 0.6716
# Epoch 17, CIFAR-10 Batch 3:   Loss: 0.0761   Validation Accuracy: 0.6924
# Epoch 17, CIFAR-10 Batch 4:   Loss: 0.0827   Validation Accuracy: 0.6828
# Epoch 17, CIFAR-10 Batch 5:   Loss: 0.0688   Validation Accuracy: 0.6816
# Epoch 18, CIFAR-10 Batch 1:   Loss: 0.0836   Validation Accuracy: 0.6882
# Epoch 18, CIFAR-10 Batch 2:   Loss: 0.0908   Validation Accuracy: 0.6728
# Epoch 18, CIFAR-10 Batch 3:   Loss: 0.0777   Validation Accuracy: 0.6900
# Epoch 18, CIFAR-10 Batch 4:   Loss: 0.0573   Validation Accuracy: 0.6880
# Epoch 18, CIFAR-10 Batch 5:   Loss: 0.0522   Validation Accuracy: 0.6908
# Epoch 19, CIFAR-10 Batch 1:   Loss: 0.0742   Validation Accuracy: 0.6830
# Epoch 19, CIFAR-10 Batch 2:   Loss: 0.0503   Validation Accuracy: 0.6892
# Epoch 19, CIFAR-10 Batch 3:   Loss: 0.0612   Validation Accuracy: 0.6862
# Epoch 19, CIFAR-10 Batch 4:   Loss: 0.0494   Validation Accuracy: 0.6898
# Epoch 19, CIFAR-10 Batch 5:   Loss: 0.0488   Validation Accuracy: 0.6858
# Epoch 20, CIFAR-10 Batch 1:   Loss: 0.0453   Validation Accuracy: 0.6920
# Epoch 20, CIFAR-10 Batch 2:   Loss: 0.0541   Validation Accuracy: 0.6910
# Epoch 20, CIFAR-10 Batch 3:   Loss: 0.0476   Validation Accuracy: 0.6934
# Epoch 20, CIFAR-10 Batch 4:   Loss: 0.0425   Validation Accuracy: 0.6888
# Epoch 20, CIFAR-10 Batch 5:   Loss: 0.0352   Validation Accuracy: 0.6922
# Epoch 21, CIFAR-10 Batch 1:   Loss: 0.0550   Validation Accuracy: 0.7004
# Epoch 21, CIFAR-10 Batch 2:   Loss: 0.0541   Validation Accuracy: 0.6938
# Epoch 21, CIFAR-10 Batch 3:   Loss: 0.0339   Validation Accuracy: 0.6902
# Epoch 21, CIFAR-10 Batch 4:   Loss: 0.0297   Validation Accuracy: 0.6884
# Epoch 21, CIFAR-10 Batch 5:   Loss: 0.0289   Validation Accuracy: 0.6886
# Epoch 22, CIFAR-10 Batch 1:   Loss: 0.0338   Validation Accuracy: 0.6986
# Epoch 22, CIFAR-10 Batch 2:   Loss: 0.0303   Validation Accuracy: 0.6896
# Epoch 22, CIFAR-10 Batch 3:   Loss: 0.0230   Validation Accuracy: 0.6992
# Epoch 22, CIFAR-10 Batch 4:   Loss: 0.0228   Validation Accuracy: 0.6946
# Epoch 22, CIFAR-10 Batch 5:   Loss: 0.0158   Validation Accuracy: 0.6934
# Epoch 23, CIFAR-10 Batch 1:   Loss: 0.0233   Validation Accuracy: 0.6972
# Epoch 23, CIFAR-10 Batch 2:   Loss: 0.0156   Validation Accuracy: 0.7004
# Epoch 23, CIFAR-10 Batch 3:   Loss: 0.0178   Validation Accuracy: 0.7050
# Epoch 23, CIFAR-10 Batch 4:   Loss: 0.0176   Validation Accuracy: 0.7022
# Epoch 23, CIFAR-10 Batch 5:   Loss: 0.0162   Validation Accuracy: 0.6918
# Epoch 24, CIFAR-10 Batch 1:   Loss: 0.0250   Validation Accuracy: 0.6958
# Epoch 24, CIFAR-10 Batch 2:   Loss: 0.0155   Validation Accuracy: 0.6984
# Epoch 24, CIFAR-10 Batch 3:   Loss: 0.0152   Validation Accuracy: 0.6972
# Epoch 24, CIFAR-10 Batch 4:   Loss: 0.0216   Validation Accuracy: 0.6936
# Epoch 24, CIFAR-10 Batch 5:   Loss: 0.0113   Validation Accuracy: 0.6932
# Epoch 25, CIFAR-10 Batch 1:   Loss: 0.0146   Validation Accuracy: 0.6968
# Epoch 25, CIFAR-10 Batch 2:   Loss: 0.0126   Validation Accuracy: 0.7016
# Epoch 25, CIFAR-10 Batch 3:   Loss: 0.0102   Validation Accuracy: 0.7016
# Epoch 25, CIFAR-10 Batch 4:   Loss: 0.0141   Validation Accuracy: 0.6920
# Epoch 25, CIFAR-10 Batch 5:   Loss: 0.0075   Validation Accuracy: 0.6958
# Epoch 26, CIFAR-10 Batch 1:   Loss: 0.0111   Validation Accuracy: 0.6906
# Epoch 26, CIFAR-10 Batch 2:   Loss: 0.0123   Validation Accuracy: 0.6998
# Epoch 26, CIFAR-10 Batch 3:   Loss: 0.0105   Validation Accuracy: 0.6912
# Epoch 26, CIFAR-10 Batch 4:   Loss: 0.0134   Validation Accuracy: 0.6950
# Epoch 26, CIFAR-10 Batch 5:   Loss: 0.0079   Validation Accuracy: 0.6978
# Epoch 27, CIFAR-10 Batch 1:   Loss: 0.0107   Validation Accuracy: 0.7004
# Epoch 27, CIFAR-10 Batch 2:   Loss: 0.0095   Validation Accuracy: 0.6982
# Epoch 27, CIFAR-10 Batch 3:   Loss: 0.0071   Validation Accuracy: 0.6912
# Epoch 27, CIFAR-10 Batch 4:   Loss: 0.0088   Validation Accuracy: 0.6866
# Epoch 27, CIFAR-10 Batch 5:   Loss: 0.0050   Validation Accuracy: 0.7014
# Epoch 28, CIFAR-10 Batch 1:   Loss: 0.0116   Validation Accuracy: 0.6990
# Epoch 28, CIFAR-10 Batch 2:   Loss: 0.0066   Validation Accuracy: 0.6992
# Epoch 28, CIFAR-10 Batch 3:   Loss: 0.0077   Validation Accuracy: 0.6922
# Epoch 28, CIFAR-10 Batch 4:   Loss: 0.0061   Validation Accuracy: 0.6896
# Epoch 28, CIFAR-10 Batch 5:   Loss: 0.0071   Validation Accuracy: 0.6986
# Epoch 29, CIFAR-10 Batch 1:   Loss: 0.0073   Validation Accuracy: 0.6840
# Epoch 29, CIFAR-10 Batch 2:   Loss: 0.0042   Validation Accuracy: 0.7028
# Epoch 29, CIFAR-10 Batch 3:   Loss: 0.0085   Validation Accuracy: 0.7020
# Epoch 29, CIFAR-10 Batch 4:   Loss: 0.0082   Validation Accuracy: 0.6930
# Epoch 29, CIFAR-10 Batch 5:   Loss: 0.0053   Validation Accuracy: 0.6900
# Epoch 30, CIFAR-10 Batch 1:   Loss: 0.0063   Validation Accuracy: 0.7008
# Epoch 30, CIFAR-10 Batch 2:   Loss: 0.0031   Validation Accuracy: 0.7052
# Epoch 30, CIFAR-10 Batch 3:   Loss: 0.0057   Validation Accuracy: 0.6968
# Epoch 30, CIFAR-10 Batch 4:   Loss: 0.0075   Validation Accuracy: 0.6884
# Epoch 30, CIFAR-10 Batch 5:   Loss: 0.0043   Validation Accuracy: 0.6934
# Epoch 31, CIFAR-10 Batch 1:   Loss: 0.0048   Validation Accuracy: 0.6996
# Epoch 31, CIFAR-10 Batch 2:   Loss: 0.0058   Validation Accuracy: 0.6976
# Epoch 31, CIFAR-10 Batch 3:   Loss: 0.0057   Validation Accuracy: 0.6952
# Epoch 31, CIFAR-10 Batch 4:   Loss: 0.0048   Validation Accuracy: 0.6892
# Epoch 31, CIFAR-10 Batch 5:   Loss: 0.0033   Validation Accuracy: 0.7012
# Epoch 32, CIFAR-10 Batch 1:   Loss: 0.0100   Validation Accuracy: 0.6988
# Epoch 32, CIFAR-10 Batch 2:   Loss: 0.0048   Validation Accuracy: 0.6940
# Epoch 32, CIFAR-10 Batch 3:   Loss: 0.0039   Validation Accuracy: 0.6998
# Epoch 32, CIFAR-10 Batch 4:   Loss: 0.0062   Validation Accuracy: 0.6884
# Epoch 32, CIFAR-10 Batch 5:   Loss: 0.0024   Validation Accuracy: 0.6966
# Epoch 33, CIFAR-10 Batch 1:   Loss: 0.0048   Validation Accuracy: 0.7038
# Epoch 33, CIFAR-10 Batch 2:   Loss: 0.0037   Validation Accuracy: 0.6986
# Epoch 33, CIFAR-10 Batch 3:   Loss: 0.0021   Validation Accuracy: 0.7022
# Epoch 33, CIFAR-10 Batch 4:   Loss: 0.0024   Validation Accuracy: 0.6890
# Epoch 33, CIFAR-10 Batch 5:   Loss: 0.0023   Validation Accuracy: 0.6988
# Epoch 34, CIFAR-10 Batch 1:   Loss: 0.0039   Validation Accuracy: 0.7010
# Epoch 34, CIFAR-10 Batch 2:   Loss: 0.0037   Validation Accuracy: 0.6904
# Epoch 34, CIFAR-10 Batch 3:   Loss: 0.0033   Validation Accuracy: 0.7002
# Epoch 34, CIFAR-10 Batch 4:   Loss: 0.0032   Validation Accuracy: 0.6938
# Epoch 34, CIFAR-10 Batch 5:   Loss: 0.0024   Validation Accuracy: 0.7014
# Epoch 35, CIFAR-10 Batch 1:   Loss: 0.0017   Validation Accuracy: 0.7110
# Epoch 35, CIFAR-10 Batch 2:   Loss: 0.0024   Validation Accuracy: 0.6958
# Epoch 35, CIFAR-10 Batch 3:   Loss: 0.0033   Validation Accuracy: 0.6944
# Epoch 35, CIFAR-10 Batch 4:   Loss: 0.0011   Validation Accuracy: 0.6912
# Epoch 35, CIFAR-10 Batch 5:   Loss: 0.0031   Validation Accuracy: 0.7070
# Epoch 36, CIFAR-10 Batch 1:   Loss: 0.0013   Validation Accuracy: 0.7116
# Epoch 36, CIFAR-10 Batch 2:   Loss: 0.0012   Validation Accuracy: 0.7096
# Epoch 36, CIFAR-10 Batch 3:   Loss: 0.0011   Validation Accuracy: 0.7076
# Epoch 36, CIFAR-10 Batch 4:   Loss: 0.0011   Validation Accuracy: 0.7040
# Epoch 36, CIFAR-10 Batch 5:   Loss: 0.0020   Validation Accuracy: 0.7098
# Epoch 37, CIFAR-10 Batch 1:   Loss: 0.0014   Validation Accuracy: 0.7104
# Epoch 37, CIFAR-10 Batch 2:   Loss: 0.0010   Validation Accuracy: 0.7080
# Epoch 37, CIFAR-10 Batch 3:   Loss: 0.0010   Validation Accuracy: 0.7010
# Epoch 37, CIFAR-10 Batch 4:   Loss: 0.0013   Validation Accuracy: 0.6972
# Epoch 37, CIFAR-10 Batch 5:   Loss: 0.0006   Validation Accuracy: 0.7092
# Epoch 38, CIFAR-10 Batch 1:   Loss: 0.0016   Validation Accuracy: 0.7050
# Epoch 38, CIFAR-10 Batch 2:   Loss: 0.0016   Validation Accuracy: 0.7052
# Epoch 38, CIFAR-10 Batch 3:   Loss: 0.0010   Validation Accuracy: 0.6878
# Epoch 38, CIFAR-10 Batch 4:   Loss: 0.0012   Validation Accuracy: 0.6928
# Epoch 38, CIFAR-10 Batch 5:   Loss: 0.0016   Validation Accuracy: 0.7028
# Epoch 39, CIFAR-10 Batch 1:   Loss: 0.0015   Validation Accuracy: 0.7070
# Epoch 39, CIFAR-10 Batch 2:   Loss: 0.0010   Validation Accuracy: 0.7010
# Epoch 39, CIFAR-10 Batch 3:   Loss: 0.0008   Validation Accuracy: 0.7048
# Epoch 39, CIFAR-10 Batch 4:   Loss: 0.0021   Validation Accuracy: 0.6952
# Epoch 39, CIFAR-10 Batch 5:   Loss: 0.0014   Validation Accuracy: 0.7074
# Epoch 40, CIFAR-10 Batch 1:   Loss: 0.0009   Validation Accuracy: 0.7040
# Epoch 40, CIFAR-10 Batch 2:   Loss: 0.0016   Validation Accuracy: 0.7050
# Epoch 40, CIFAR-10 Batch 3:   Loss: 0.0007   Validation Accuracy: 0.7052
# Epoch 40, CIFAR-10 Batch 4:   Loss: 0.0018   Validation Accuracy: 0.7078
# Epoch 40, CIFAR-10 Batch 5:   Loss: 0.0005   Validation Accuracy: 0.7062
# Epoch 41, CIFAR-10 Batch 1:   Loss: 0.0008   Validation Accuracy: 0.7034
# Epoch 41, CIFAR-10 Batch 2:   Loss: 0.0013   Validation Accuracy: 0.7034
# Epoch 41, CIFAR-10 Batch 3:   Loss: 0.0006   Validation Accuracy: 0.7036
# Epoch 41, CIFAR-10 Batch 4:   Loss: 0.0024   Validation Accuracy: 0.7100
# Epoch 41, CIFAR-10 Batch 5:   Loss: 0.0006   Validation Accuracy: 0.6984
# Epoch 42, CIFAR-10 Batch 1:   Loss: 0.0008   Validation Accuracy: 0.6832
# Epoch 42, CIFAR-10 Batch 2:   Loss: 0.0013   Validation Accuracy: 0.7096
# Epoch 42, CIFAR-10 Batch 3:   Loss: 0.0004   Validation Accuracy: 0.6986
# Epoch 42, CIFAR-10 Batch 4:   Loss: 0.0008   Validation Accuracy: 0.7008
# Epoch 42, CIFAR-10 Batch 5:   Loss: 0.0006   Validation Accuracy: 0.7084
# Epoch 43, CIFAR-10 Batch 1:   Loss: 0.0005   Validation Accuracy: 0.7020
# Epoch 43, CIFAR-10 Batch 2:   Loss: 0.0008   Validation Accuracy: 0.7012
# Epoch 43, CIFAR-10 Batch 3:   Loss: 0.0003   Validation Accuracy: 0.7010
# Epoch 43, CIFAR-10 Batch 4:   Loss: 0.0005   Validation Accuracy: 0.7036
# Epoch 43, CIFAR-10 Batch 5:   Loss: 0.0006   Validation Accuracy: 0.7004
# Epoch 44, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7000
# Epoch 44, CIFAR-10 Batch 2:   Loss: 0.0008   Validation Accuracy: 0.7052
# Epoch 44, CIFAR-10 Batch 3:   Loss: 0.0005   Validation Accuracy: 0.7018
# Epoch 44, CIFAR-10 Batch 4:   Loss: 0.0008   Validation Accuracy: 0.7134
# Epoch 44, CIFAR-10 Batch 5:   Loss: 0.0010   Validation Accuracy: 0.6958
# Epoch 45, CIFAR-10 Batch 1:   Loss: 0.0005   Validation Accuracy: 0.6948
# Epoch 45, CIFAR-10 Batch 2:   Loss: 0.0005   Validation Accuracy: 0.7014
# Epoch 45, CIFAR-10 Batch 3:   Loss: 0.0004   Validation Accuracy: 0.6998
# Epoch 45, CIFAR-10 Batch 4:   Loss: 0.0005   Validation Accuracy: 0.7072
# Epoch 45, CIFAR-10 Batch 5:   Loss: 0.0007   Validation Accuracy: 0.7024
# Epoch 46, CIFAR-10 Batch 1:   Loss: 0.0006   Validation Accuracy: 0.7072
# Epoch 46, CIFAR-10 Batch 2:   Loss: 0.0008   Validation Accuracy: 0.6994
# Epoch 46, CIFAR-10 Batch 3:   Loss: 0.0008   Validation Accuracy: 0.7038
# Epoch 46, CIFAR-10 Batch 4:   Loss: 0.0007   Validation Accuracy: 0.7070
# Epoch 46, CIFAR-10 Batch 5:   Loss: 0.0004   Validation Accuracy: 0.7078
# Epoch 47, CIFAR-10 Batch 1:   Loss: 0.0004   Validation Accuracy: 0.6990
# Epoch 47, CIFAR-10 Batch 2:   Loss: 0.0002   Validation Accuracy: 0.7040
# Epoch 47, CIFAR-10 Batch 3:   Loss: 0.0003   Validation Accuracy: 0.7016
# Epoch 47, CIFAR-10 Batch 4:   Loss: 0.0005   Validation Accuracy: 0.7118
# Epoch 47, CIFAR-10 Batch 5:   Loss: 0.0008   Validation Accuracy: 0.7080
# Epoch 48, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7066
# Epoch 48, CIFAR-10 Batch 2:   Loss: 0.0004   Validation Accuracy: 0.7070
# Epoch 48, CIFAR-10 Batch 3:   Loss: 0.0002   Validation Accuracy: 0.7004
# Epoch 48, CIFAR-10 Batch 4:   Loss: 0.0005   Validation Accuracy: 0.7094
# Epoch 48, CIFAR-10 Batch 5:   Loss: 0.0006   Validation Accuracy: 0.7098
# Epoch 49, CIFAR-10 Batch 1:   Loss: 0.0024   Validation Accuracy: 0.7038
# Epoch 49, CIFAR-10 Batch 2:   Loss: 0.0004   Validation Accuracy: 0.6974
# Epoch 49, CIFAR-10 Batch 3:   Loss: 0.0002   Validation Accuracy: 0.7074
# Epoch 49, CIFAR-10 Batch 4:   Loss: 0.0003   Validation Accuracy: 0.7040
# Epoch 49, CIFAR-10 Batch 5:   Loss: 0.0003   Validation Accuracy: 0.7100
# Epoch 50, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7010
# Epoch 50, CIFAR-10 Batch 2:   Loss: 0.0002   Validation Accuracy: 0.7084
# Epoch 50, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7102
# Epoch 50, CIFAR-10 Batch 4:   Loss: 0.0003   Validation Accuracy: 0.7064
# Epoch 50, CIFAR-10 Batch 5:   Loss: 0.0005   Validation Accuracy: 0.7130
# Epoch 51, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.6990
# Epoch 51, CIFAR-10 Batch 2:   Loss: 0.0004   Validation Accuracy: 0.7010
# Epoch 51, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7020
# Epoch 51, CIFAR-10 Batch 4:   Loss: 0.0003   Validation Accuracy: 0.7072
# Epoch 51, CIFAR-10 Batch 5:   Loss: 0.0004   Validation Accuracy: 0.7080
# Epoch 52, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7060
# Epoch 52, CIFAR-10 Batch 2:   Loss: 0.0003   Validation Accuracy: 0.6996
# Epoch 52, CIFAR-10 Batch 3:   Loss: 0.0003   Validation Accuracy: 0.7064
# Epoch 52, CIFAR-10 Batch 4:   Loss: 0.0002   Validation Accuracy: 0.7006
# Epoch 52, CIFAR-10 Batch 5:   Loss: 0.0002   Validation Accuracy: 0.7010
# Epoch 53, CIFAR-10 Batch 1:   Loss: 0.0007   Validation Accuracy: 0.7024
# Epoch 53, CIFAR-10 Batch 2:   Loss: 0.0013   Validation Accuracy: 0.7058
# Epoch 53, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7120
# Epoch 53, CIFAR-10 Batch 4:   Loss: 0.0003   Validation Accuracy: 0.7074
# Epoch 53, CIFAR-10 Batch 5:   Loss: 0.0007   Validation Accuracy: 0.7070
# Epoch 54, CIFAR-10 Batch 1:   Loss: 0.0012   Validation Accuracy: 0.7044
# Epoch 54, CIFAR-10 Batch 2:   Loss: 0.0002   Validation Accuracy: 0.7010
# Epoch 54, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.6924
# Epoch 54, CIFAR-10 Batch 4:   Loss: 0.0004   Validation Accuracy: 0.7036
# Epoch 54, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7018
# Epoch 55, CIFAR-10 Batch 1:   Loss: 0.0024   Validation Accuracy: 0.6970
# Epoch 55, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7012
# Epoch 55, CIFAR-10 Batch 3:   Loss: 0.0012   Validation Accuracy: 0.7018
# Epoch 55, CIFAR-10 Batch 4:   Loss: 0.0019   Validation Accuracy: 0.6976
# Epoch 55, CIFAR-10 Batch 5:   Loss: 0.0003   Validation Accuracy: 0.7126
# Epoch 56, CIFAR-10 Batch 1:   Loss: 0.0004   Validation Accuracy: 0.7154
# Epoch 56, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7136
# Epoch 56, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.6938
# Epoch 56, CIFAR-10 Batch 4:   Loss: 0.0011   Validation Accuracy: 0.7108
# Epoch 56, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7044
# Epoch 57, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7026
# Epoch 57, CIFAR-10 Batch 2:   Loss: 0.0002   Validation Accuracy: 0.7022
# Epoch 57, CIFAR-10 Batch 3:   Loss: 0.0002   Validation Accuracy: 0.7106
# Epoch 57, CIFAR-10 Batch 4:   Loss: 0.0005   Validation Accuracy: 0.7032
# Epoch 57, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7160
# Epoch 58, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7076
# Epoch 58, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7088
# Epoch 58, CIFAR-10 Batch 3:   Loss: 0.0002   Validation Accuracy: 0.7108
# Epoch 58, CIFAR-10 Batch 4:   Loss: 0.0005   Validation Accuracy: 0.6970
# Epoch 58, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7024
# Epoch 59, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7108
# Epoch 59, CIFAR-10 Batch 2:   Loss: 0.0004   Validation Accuracy: 0.7048
# Epoch 59, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7066
# Epoch 59, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7026
# Epoch 59, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7070
# Epoch 60, CIFAR-10 Batch 1:   Loss: 0.0011   Validation Accuracy: 0.7110
# Epoch 60, CIFAR-10 Batch 2:   Loss: 0.0003   Validation Accuracy: 0.7036
# Epoch 60, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7102
# Epoch 60, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7052
# Epoch 60, CIFAR-10 Batch 5:   Loss: 0.0002   Validation Accuracy: 0.7068
# Epoch 61, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7082
# Epoch 61, CIFAR-10 Batch 2:   Loss: 0.0002   Validation Accuracy: 0.7104
# Epoch 61, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7008
# Epoch 61, CIFAR-10 Batch 4:   Loss: 0.0002   Validation Accuracy: 0.7078
# Epoch 61, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7162
# Epoch 62, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7068
# Epoch 62, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7084
# Epoch 62, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7014
# Epoch 62, CIFAR-10 Batch 4:   Loss: 0.0004   Validation Accuracy: 0.7098
# Epoch 62, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7154
# Epoch 63, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7138
# Epoch 63, CIFAR-10 Batch 2:   Loss: 0.0003   Validation Accuracy: 0.6994
# Epoch 63, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7074
# Epoch 63, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7064
# Epoch 63, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7104
# Epoch 64, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7066
# Epoch 64, CIFAR-10 Batch 2:   Loss: 0.0002   Validation Accuracy: 0.7046
# Epoch 64, CIFAR-10 Batch 3:   Loss: 0.0002   Validation Accuracy: 0.7070
# Epoch 64, CIFAR-10 Batch 4:   Loss: 0.0005   Validation Accuracy: 0.7022
# Epoch 64, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7094
# Epoch 65, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7128
# Epoch 65, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.6986
# Epoch 65, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7166
# Epoch 65, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7116
# Epoch 65, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7154
# Epoch 66, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7032
# Epoch 66, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7020
# Epoch 66, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7122
# Epoch 66, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7012
# Epoch 66, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7094
# Epoch 67, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7048
# Epoch 67, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.6980
# Epoch 67, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7166
# Epoch 67, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7110
# Epoch 67, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7120
# Epoch 68, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7126
# Epoch 68, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7092
# Epoch 68, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7138
# Epoch 68, CIFAR-10 Batch 4:   Loss: 0.0004   Validation Accuracy: 0.7078
# Epoch 68, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7100
# Epoch 69, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7152
# Epoch 69, CIFAR-10 Batch 2:   Loss: 0.0002   Validation Accuracy: 0.7036
# Epoch 69, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7096
# Epoch 69, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7052
# Epoch 69, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7074
# Epoch 70, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7084
# Epoch 70, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7124
# Epoch 70, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7046
# Epoch 70, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7000
# Epoch 70, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7058
# Epoch 71, CIFAR-10 Batch 1:   Loss: 0.0003   Validation Accuracy: 0.7104
# Epoch 71, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7062
# Epoch 71, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7048
# Epoch 71, CIFAR-10 Batch 4:   Loss: 0.0002   Validation Accuracy: 0.6994
# Epoch 71, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7090
# Epoch 72, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7130
# Epoch 72, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7080
# Epoch 72, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7114
# Epoch 72, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7048
# Epoch 72, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7064
# Epoch 73, CIFAR-10 Batch 1:   Loss: 0.0002   Validation Accuracy: 0.7086
# Epoch 73, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7134
# Epoch 73, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7100
# Epoch 73, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7012
# Epoch 73, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7068
# Epoch 74, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7048
# Epoch 74, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7104
# Epoch 74, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7050
# Epoch 74, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7124
# Epoch 74, CIFAR-10 Batch 5:   Loss: 0.0002   Validation Accuracy: 0.7064
# Epoch 75, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7160
# Epoch 75, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7132
# Epoch 75, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7128
# Epoch 75, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7086
# Epoch 75, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7180
# Epoch 76, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7076
# Epoch 76, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7102
# Epoch 76, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7072
# Epoch 76, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.6982
# Epoch 76, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7030
# Epoch 77, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7028
# Epoch 77, CIFAR-10 Batch 2:   Loss: 0.0004   Validation Accuracy: 0.7022
# Epoch 77, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7078
# Epoch 77, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7054
# Epoch 77, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7036
# Epoch 78, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7096
# Epoch 78, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7114
# Epoch 78, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7102
# Epoch 78, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7024
# Epoch 78, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7014
# Epoch 79, CIFAR-10 Batch 1:   Loss: 0.0019   Validation Accuracy: 0.7056
# Epoch 79, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7034
# Epoch 79, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7124
# Epoch 79, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7072
# Epoch 79, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.6934
# Epoch 80, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7024
# Epoch 80, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7020
# Epoch 80, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7066
# Epoch 80, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7060
# Epoch 80, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7078
# Epoch 81, CIFAR-10 Batch 1:   Loss: 0.0004   Validation Accuracy: 0.7110
# Epoch 81, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7030
# Epoch 81, CIFAR-10 Batch 3:   Loss: 0.0002   Validation Accuracy: 0.7080
# Epoch 81, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7024
# Epoch 81, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7062
# Epoch 82, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7074
# Epoch 82, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7022
# Epoch 82, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7054
# Epoch 82, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7136
# Epoch 82, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7104
# Epoch 83, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7110
# Epoch 83, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7054
# Epoch 83, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7122
# Epoch 83, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7096
# Epoch 83, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7126
# Epoch 84, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7032
# Epoch 84, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7040
# Epoch 84, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7106
# Epoch 84, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7090
# Epoch 84, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7098
# Epoch 85, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7102
# Epoch 85, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7076
# Epoch 85, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7132
# Epoch 85, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7126
# Epoch 85, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7070
# Epoch 86, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7054
# Epoch 86, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7104
# Epoch 86, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7144
# Epoch 86, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7026
# Epoch 86, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7182
# Epoch 87, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7138
# Epoch 87, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7090
# Epoch 87, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7140
# Epoch 87, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7050
# Epoch 87, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7190
# Epoch 88, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7036
# Epoch 88, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7076
# Epoch 88, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7142
# Epoch 88, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7136
# Epoch 88, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7134
# Epoch 89, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7138
# Epoch 89, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7062
# Epoch 89, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7078
# Epoch 89, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7078
# Epoch 89, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7152
# Epoch 90, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7084
# Epoch 90, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7108
# Epoch 90, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7112
# Epoch 90, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7050
# Epoch 90, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7090
# Epoch 91, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7036
# Epoch 91, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7004
# Epoch 91, CIFAR-10 Batch 3:   Loss: 0.0001   Validation Accuracy: 0.7076
# Epoch 91, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7090
# Epoch 91, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7144
# Epoch 92, CIFAR-10 Batch 1:   Loss: 0.0001   Validation Accuracy: 0.7054
# Epoch 92, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7052
# Epoch 92, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7070
# Epoch 92, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7020
# Epoch 92, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7060
# Epoch 93, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7056
# Epoch 93, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.6958
# Epoch 93, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7092
# Epoch 93, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7092
# Epoch 93, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7086
# Epoch 94, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7100
# Epoch 94, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7086
# Epoch 94, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7120
# Epoch 94, CIFAR-10 Batch 4:   Loss: 0.0070   Validation Accuracy: 0.6996
# Epoch 94, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7044
# Epoch 95, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7114
# Epoch 95, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7046
# Epoch 95, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7132
# Epoch 95, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7064
# Epoch 95, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7054
# Epoch 96, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7120
# Epoch 96, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7018
# Epoch 96, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7070
# Epoch 96, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7180
# Epoch 96, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7038
# Epoch 97, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7086
# Epoch 97, CIFAR-10 Batch 2:   Loss: 0.0008   Validation Accuracy: 0.7002
# Epoch 97, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7070
# Epoch 97, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7028
# Epoch 97, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7070
# Epoch 98, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7108
# Epoch 98, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7028
# Epoch 98, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7120
# Epoch 98, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7106
# Epoch 98, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7086
# Epoch 99, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7092
# Epoch 99, CIFAR-10 Batch 2:   Loss: 0.0000   Validation Accuracy: 0.7102
# Epoch 99, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7154
# Epoch 99, CIFAR-10 Batch 4:   Loss: 0.0001   Validation Accuracy: 0.7076
# Epoch 99, CIFAR-10 Batch 5:   Loss: 0.0001   Validation Accuracy: 0.7056
# Epoch 100, CIFAR-10 Batch 1:   Loss: 0.0000   Validation Accuracy: 0.7110
# Epoch 100, CIFAR-10 Batch 2:   Loss: 0.0001   Validation Accuracy: 0.7094
# Epoch 100, CIFAR-10 Batch 3:   Loss: 0.0000   Validation Accuracy: 0.7092
# Epoch 100, CIFAR-10 Batch 4:   Loss: 0.0000   Validation Accuracy: 0.7034
# Epoch 100, CIFAR-10 Batch 5:   Loss: 0.0000   Validation Accuracy: 0.7090

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.70498046875

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
